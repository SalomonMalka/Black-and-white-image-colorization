# %% [markdown]
# <a href="https://colab.research.google.com/github/SalomonMalka/Black-and-white-image-colorization/blob/main/Black_and_white_image_colorization_RGB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Colorization with U-Net and GAN Tutorial - Version RGB

# %% [markdown]
# # 1 - Imports and data loading

# %%
# !pip install piqa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: piqa in /usr/local/lib/python3.8/dist-packages (1.2.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from piqa) (1.13.0+cu116)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from piqa) (0.14.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.8.0->piqa) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.9.0->piqa) (2.25.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.9.0->piqa) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.9.0->piqa) (1.21.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.9.0->piqa) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.9.0->piqa) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.9.0->piqa) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.9.0->piqa) (2022.12.7)

# %%
import os
import glob
import time
import numpy as np
from PIL import Image
from pathlib import Path
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from skimage.color import rgb2lab, lab2rgb
from scipy.stats import wasserstein_distance

import torch
from torch import nn, optim
from torchvision import transforms
from torchvision.utils import make_grid
from torch.utils.data import Dataset, DataLoader
import piqa
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
use_colab = None

# %% [markdown]
# ### 1.1 - Imports in colab

# %% [markdown]
# The following code install fastai, a library needed essentially in this project to use the COCO database.

# %%
# !pip install fastai==2.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastai==2.4
#   Downloading fastai-2.4-py3-none-any.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.9/187.9 KB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (1.7.3)
# Requirement already satisfied: pillow>6.0.0 in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (7.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (1.0.2)
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (22.0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (21.3)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (0.14.0+cu116)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (3.2.2)
# Collecting torch<1.10,>=1.7.0
#   Downloading torch-1.9.1-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.4/831.4 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (6.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (1.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (2.25.1)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (3.4.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from fastai==2.4) (1.3.5)
# Collecting fastcore<1.4,>=1.3.8
#   Downloading fastcore-1.3.29-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (2.11.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (1.10.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (2.4.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (1.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (6.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (57.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (0.7.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (2.0.7)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (8.1.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (3.0.11)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4->fastai==2.4) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->fastai==2.4) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fastai==2.4) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fastai==2.4) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fastai==2.4) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->fastai==2.4) (2.10)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch<1.10,>=1.7.0->fastai==2.4) (4.4.0)
# Collecting torchvision>=0.8.2
#   Downloading torchvision-0.14.1-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 54.7 MB/s eta 0:00:00
#   Downloading torchvision-0.14.0-cp38-cp38-manylinux1_x86_64.whl (24.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 73.2 MB/s eta 0:00:00
#   Downloading torchvision-0.13.1-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 78.8 MB/s eta 0:00:00
#   Downloading torchvision-0.13.0-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 19.8 MB/s eta 0:00:00
#   Downloading torchvision-0.12.0-cp38-cp38-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 66.1 MB/s eta 0:00:00
#   Downloading torchvision-0.11.3-cp38-cp38-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 69.9 MB/s eta 0:00:00
#   Downloading torchvision-0.11.2-cp38-cp38-manylinux1_x86_64.whl (23.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 58.6 MB/s eta 0:00:00
#   Downloading torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl (23.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 17.7 MB/s eta 0:00:00
#   Downloading torchvision-0.10.1-cp38-cp38-manylinux1_x86_64.whl (22.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.1/22.1 MB 76.1 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->fastai==2.4) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->fastai==2.4) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->fastai==2.4) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->fastai==2.4) (2022.7)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->fastai==2.4) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->fastai==2.4) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.1->matplotlib->fastai==2.4) (1.15.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai==2.4) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai==2.4) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai==2.4) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<4->fastai==2.4) (2.0.1)
# Installing collected packages: torch, torchvision, fastcore, fastai
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
#   Attempting uninstall: fastcore
#     Found existing installation: fastcore 1.5.27
#     Uninstalling fastcore-1.5.27:
#       Successfully uninstalled fastcore-1.5.27
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.7.10
#     Uninstalling fastai-2.7.10:
#       Successfully uninstalled fastai-2.7.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.9.1 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.9.1 which is incompatible.
# Successfully installed fastai-2.4 fastcore-1.3.29 torch-1.9.1 torchvision-0.10.1

# %% [markdown]
# The following will download about 20,000 images from COCO dataset.

# %%
from fastai.data.external import untar_data, URLs
coco_path = untar_data(URLs.COCO_SAMPLE)
coco_path = str(coco_path) + "/train_sample"
use_colab = True
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
if use_colab == True:
    path = coco_path
else:
    path = "/coco_dataset"
    
paths = glob.glob(path + "/*.jpg") # Grabbing all the image file names
np.random.seed(123)
paths_subset = np.random.choice(paths, 10_000, replace=False) # choosing 10_000 images randomly
rand_idxs = np.random.permutation(10_000)
train_idxs = rand_idxs[:8000] # choosing the first 8000 as training set
val_idxs = rand_idxs[8000:] # choosing last 2000 as validation set
train_paths = paths_subset[train_idxs]
val_paths = paths_subset[val_idxs]
print(f"Size of train and validation set: {len(train_paths)}, {len(val_paths)}")
# Out:
# Size of train and validation set: 8000, 2000

# %% [markdown]
# Print some images from the train dataset

# %%
_, axes = plt.subplots(4, 4, figsize=(10, 10))
for ax, img_path in zip(axes.flatten(), train_paths):
    ax.imshow(Image.open(img_path))
    ax.axis("off")

# %% [markdown]
# ### 1.2 - Making Datasets and DataLoaders

# %% [markdown]
# We separate the data into **L\*a\*b** channels. The **L** channel will be the **black-and-white** images and the **a*b** channels we aim to **predict**.

# %%
SIZE = 256
class ColorizationDataset(Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE),  Image.BICUBIC),
                transforms.RandomHorizontalFlip(), # A little data augmentation!
            ])
        elif split == 'val':
            self.transforms = transforms.Resize((SIZE, SIZE),  Image.BICUBIC)
        
        self.split = split
        self.size = SIZE
        self.paths = paths
    
    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert("RGB")
        img = self.transforms(img)
        img = np.array(img)
        img_lab = rgb2lab(img).astype("float32") # Converting RGB to L*a*b
        img_lab = transforms.ToTensor()(img_lab)
        L = img_lab[[0], ...] / 50. - 1. # Between -1 and 1
        color = transforms.ToTensor()(img)
        
        return {'L': L, 'color': color}
    
    def __len__(self):
        return len(self.paths)

def make_dataloaders(batch_size=16, n_workers=4, pin_memory=True, **kwargs): # A handy function to make our dataloaders
    dataset = ColorizationDataset(**kwargs)
    dataloader = DataLoader(dataset, batch_size=batch_size, num_workers=n_workers,
                            pin_memory=pin_memory)
    return dataloader

# %% [markdown]
# Create train and validation dataloader

# %%
train_dl = make_dataloaders(paths=train_paths, split='train')
val_dl = make_dataloaders(paths=val_paths, split='val')

# print the dimention of the data
data = next(iter(train_dl))
Ls, colors_ = data['L'], data['color']
print("L channel image shape :", Ls.shape)
print("color channel image shape :", colors_.shape)
print(f"Lenght of train and validation set batches: {len(train_dl)}, {len(val_dl)}")
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   self.size = _setup_size(size, error_msg="Please provide only two dimensions (h, w) for size.")
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   assert self._num_workers == 0
# L channel image shape : torch.Size([16, 1, 256, 256])
# color channel image shape : torch.Size([16, 3, 256, 256])
# Lenght of train and validation set batches: 500, 125

# %% [markdown]
# Plot the L, a and b channel of an image from the data.

# %%
import matplotlib.colors as colors


data = next(iter(train_dl))
data['L'].shape

L_channel = data['L'][0][0]
color_channel = data['color'][0]

fig, axes = plt.subplots(1, 2, figsize = (15,15))
axes[0].imshow(L_channel, cmap = 'gray')
axes[0].set_xticks([])
axes[0].set_yticks([])
axes[0].set_title("L* Channel")

axes[1].imshow(color_channel.permute(1,2,0))
axes[1].set_xticks([])
axes[1].set_yticks([])
axes[1].set_title("color Channel")

plt.savefig("Lab_channel_example.jpg")
plt.show()

# %% [markdown]
# ### 1.3 Losses - example

# %% [markdown]
# # 2 - Create the model

# %% [markdown]
# ### 2.0 - Utility functions

# %%
class AverageMeter:
    def __init__(self):
        self.reset()
        
    def reset(self):
        self.count, self.avg, self.sum = [0.] * 3
    
    def update(self, val, count=1):
        self.count += count
        self.sum += count * val
        self.avg = self.sum / self.count

def create_loss_meters():
    loss_D_fake = AverageMeter()
    loss_D_real = AverageMeter()
    loss_D = AverageMeter()
    loss_G_GAN = AverageMeter()
    loss_G_L1 = AverageMeter()
    loss_G = AverageMeter()
    
    return {'loss_D_fake': loss_D_fake,
            'loss_D_real': loss_D_real,
            'loss_D': loss_D,
            'loss_G_GAN': loss_G_GAN,
            'loss_G_L1': loss_G_L1,
            'loss_G': loss_G}

def update_losses(model, loss_meter_dict, count):
    for loss_name, loss_meter in loss_meter_dict.items():
        loss = getattr(model, loss_name)
        loss_meter.update(loss.item(), count=count)
    
def visualize(model, data, save=True):
    model.net_G.eval()
    with torch.no_grad():
        model.setup_input(data)
        model.forward()
    model.net_G.train()
    fake_color = model.fake_color.detach()
    real_color = model.ab
    L = model.L
    fake_imgs = lab_to_rgb(L, fake_color)
    real_imgs = lab_to_rgb(L, real_color)
    fig = plt.figure(figsize=(15, 8))
    for i in range(5):
        ax = plt.subplot(3, 5, i + 1)
        ax.imshow(L[i][0].cpu(), cmap='gray')
        ax.axis("off")
        ax = plt.subplot(3, 5, i + 1 + 5)
        ax.imshow(fake_imgs[i])
        ax.axis("off")
        ax = plt.subplot(3, 5, i + 1 + 10)
        ax.imshow(real_imgs[i])
        ax.axis("off")
    plt.show()
    if save:
        fig.savefig(f"colorization_{time.time()}.png")

def log_results(loss_meter_dict):
    for loss_name, loss_meter in loss_meter_dict.items():
        print(f"{loss_name}: {loss_meter.avg:.5f}")

# %% [markdown]
# ### 2.1 - Main Model

# %% [markdown]
# We use fastai and torchvision model to create a Unet composed with resnet18 architechture as the encoder part.

# %%
#!pip install fastai==2.4
from fastai.vision.learner import create_body
from torchvision.models.resnet import resnet18
from fastai.vision.models.unet import DynamicUnet

# %%
def ResUnet(n_input=1, n_output=2, size=256):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    body = create_body(resnet18, pretrained=True, n_in=n_input, cut=-2)
    for param in body.parameters():
      param.requires_grad = False
    net_G = DynamicUnet(body, n_output, (size, size), y_range=(0,1)).to(device)
    return net_G

# %% [markdown]
# ### 2.2 Training the model

# %%
save_rep = 'MSE_training/'

if not os.path.exists(save_rep):
  os.makedirs(save_rep)

def visualize_images(L, ab, preds, save = False, title = ''):
  fake_image = lab_to_rgb(L,preds)
  real_image = lab_to_rgb(L,ab)
  # plot the images
  fig = plt.figure(figsize=(15, 8))
  for i in range(5):
    ax = plt.subplot(3, 5, i + 1)
    ax.imshow(L[i][0].cpu(), cmap='gray')
    ax.axis("off")
    ax = plt.subplot(3, 5, i + 1 + 5)
    ax.imshow(fake_image[i])
    ax.axis("off")
    ax = plt.subplot(3, 5, i + 1 + 10)
    ax.imshow(real_image[i])
    ax.axis("off")
  if save:
    plt.savefig(save_rep+title+'.jpg')

def visualize_images_RGB(L,original, preds, save = False, title = ''):
  original_image = original.cpu()
  predicted_image = preds.cpu()

  # plot the images
  fig = plt.figure(figsize=(15, 8))
  for i in range(5):
    ax = plt.subplot(3, 5, i + 1)
    ax.imshow(L[i][0].cpu(), cmap='gray')
    ax.axis("off")
    ax = plt.subplot(3, 5, i + 1 + 5)
    ax.imshow(predicted_image[i].permute(1,2,0))
    ax.axis("off")
    ax = plt.subplot(3, 5, i + 1 + 10)
    ax.imshow(original_image[i].permute(1,2,0))
    ax.axis("off")
  plt.show()
  if save:
    plt.savefig(save_rep+title+'.jpg')

# %%
L1_distance_array = []
L1_val_array = []
MSE_distance_array = []

def train_model(model, train_dl, opt, criterion, epochs, val_dl, visualize_every = 200):
  for e in range(epochs):
    loss_meter = AverageMeter()
    val_loss_meter = AverageMeter()
    counter = 0
    for data in tqdm(train_dl):
      L, color = data['L'].to(device), data['color'].to(device)
      preds = model(L)

      print(f"preds -------------- min {torch.min(preds)},max {torch.max(preds)}")
      print(f"origs -------------- min {torch.min(color)},max {torch.max(color)}")
      # visualize predicted images and loss every visualize_every cycles
      if counter % visualize_every == 0:
        visualize_images_RGB(L.detach(),color.detach(),preds.detach(), save = False)      
        print(f"L1 Loss: {loss_meter.avg:.5f}")
      counter += 1
      
      loss = criterion(preds, color)
      L1_loss = nn.L1Loss()(preds.detach(), color.detach())
      MSE_loss = nn.MSELoss()(preds.detach(), color.detach())
      opt.zero_grad()
      loss.backward()
      opt.step()
      loss_meter.update(loss.item(), L.size(0))
      
      # save different losses
      L1_distance_array.append(L1_loss.item())
      MSE_distance_array.append(MSE_loss.item())
    
    visualize_images(L.detach(),color.detach(),preds.detach(), save = True, title = str(e))
    print(f"Epoch {e + 1}/{epochs}")
    print(f"L1 Loss: {loss_meter.avg:.5f}")
    for data in tqdm(val_dl):
      L, color = data['L'].to(device), data['color'].to(device)
      preds = model(L)
      
      loss = criterion(torch.cat(L,preds), torch.cat(L,color))
      val_loss_meter.update(loss.item(), L.size(0))

      L1_val_array.append(L1_loss.item())
    print(f"L1 Validation Loss: {val_loss_meter.avg:.5f}")

torch.cuda.empty_cache()
unet = ResUnet(n_input=1, n_output=3, size=256)
opt = optim.Adam(unet.parameters(), lr=1e-4)
criterion = piqa.LPIPS(network='vgg').to(device)
num_epochs = 10
train_model(unet, train_dl, opt, criterion, num_epochs, val_dl)
torch.save(unet.state_dict(), "res18-unet.pt")
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# Downloading: "https://github.com/richzhang/PerceptualSimilarity/raw/master/lpips/weights/v0.1/vgg.pth" to /root/.cache/torch/hub/checkpoints/vgg.pth
#   0%|          | 0.00/7.12k [00:00<?, ?B/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   assert self._num_workers == 0
# <ipython-input-20-5bc3bd14626b>:14: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   print(f"preds -------------- min {torch.min(preds)},max {torch.max(preds)}")
# <ipython-input-20-5bc3bd14626b>:18: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   visualize_images_RGB(L.detach(),color.detach(),preds.detach(), save = False)
# preds -------------- min TensorBase(0.3672, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7105, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# <ipython-input-17-f4a04f961291>:26: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   predicted_image = preds.cpu()
# <ipython-input-17-f4a04f961291>:35: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   ax.imshow(predicted_image[i].permute(1,2,0))
# L1 Loss: 0.00000
# /usr/local/lib/python3.8/dist-packages/piqa/utils/__init__.py:77: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   shapes = [tuple(t.shape) for t in tensors]
# /usr/local/lib/python3.8/dist-packages/piqa/utils/__init__.py:81: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   assert t.device == device, f"Expected all tensors to be on the same device, but got {str(t.device)} and {str(device)}."
# /usr/local/lib/python3.8/dist-packages/piqa/utils/__init__.py:86: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   assert t.dim() == dim_range[0], f"Expected number of dimensions to be ' {dim_range[0]}, but got {t.dim()}."
# /usr/local/lib/python3.8/dist-packages/piqa/utils/__init__.py:94: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   assert t.size(1) == n_channels, f"Expected number of channels to be {n_channels}, but got {t.size(1)}."
# /usr/local/lib/python3.8/dist-packages/piqa/utils/__init__.py:97: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   assert value_range[0] <= t.min(), f"Expected all values to be greater or equal to {value_range[0]}, but got {t.min().item()}."
# /usr/local/lib/python3.8/dist-packages/piqa/utils/__init__.py:98: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   assert t.max() <= value_range[1], f"Expected all values to be lower or equal to {value_range[1]}, but got {t.max().item()}."
# /usr/local/lib/python3.8/dist-packages/piqa/lpips.py:206: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   input = (input - self.shift) / self.scale
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py:459: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   This module supports :ref:`TensorFloat32<tf32_on_ampere>`.
# /usr/local/lib/python3.8/dist-packages/piqa/utils/functional.py:380: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   x = x.sum(dim=dims, keepdim=keepdim)
# /usr/local/lib/python3.8/dist-packages/piqa/utils/functional.py:381: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   x = x.sqrt()
# /usr/local/lib/python3.8/dist-packages/piqa/lpips.py:213: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   fx = fx / l2_norm(fx, dims=[1], keepdim=True)
# /usr/local/lib/python3.8/dist-packages/piqa/lpips.py:216: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   mse = ((fx - fy) ** 2).mean(dim=(-1, -2), keepdim=True)
# /usr/local/lib/python3.8/dist-packages/piqa/lpips.py:217: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   residuals.append(lin(mse).flatten())
# /usr/local/lib/python3.8/dist-packages/piqa/lpips.py:219: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   l = torch.stack(residuals, dim=-1).sum(dim=-1)
# /usr/local/lib/python3.8/dist-packages/piqa/utils/__init__.py:117: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   return x.mean()
# <ipython-input-20-5bc3bd14626b>:23: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   L1_loss = nn.L1Loss()(preds.detach(), color.detach())
# <ipython-input-20-5bc3bd14626b>:24: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   MSE_loss = nn.MSELoss()(preds.detach(), color.detach())
# <ipython-input-20-5bc3bd14626b>:28: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   loss_meter.update(loss.item(), L.size(0))
# <ipython-input-20-5bc3bd14626b>:31: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   L1_distance_array.append(L1_loss.item())
# <ipython-input-20-5bc3bd14626b>:32: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:350.)
#   MSE_distance_array.append(MSE_loss.item())
# preds -------------- min TensorBase(0.3002, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7463, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.3537, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.6871, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.3655, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7251, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.3765, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7153, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.3273, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7015, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2870, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7266, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2533, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8261, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2834, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7522, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.3211, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7156, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.3126, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.6907, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.3221, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.6975, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2950, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.6932, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2972, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7007, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2973, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7119, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2663, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7317, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2704, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7143, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2613, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7216, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2675, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7367, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2540, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7428, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2683, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7390, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2707, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7304, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2627, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7376, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2831, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7161, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2643, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7313, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2725, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7568, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2445, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7502, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2676, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7403, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2763, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7411, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2620, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7255, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2552, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7221, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2491, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7397, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2427, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7459, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2300, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7689, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2283, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7623, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2324, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7718, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2171, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7536, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2265, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7705, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2350, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7515, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2244, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7765, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2188, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7685, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2166, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7828, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2277, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7811, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1839, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8032, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1934, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7890, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2043, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7999, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2065, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7899, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1911, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8024, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2012, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7664, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1981, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7776, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2009, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7874, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1963, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8026, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1841, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7939, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.2009, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7978, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1900, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7855, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1862, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7857, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1790, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7834, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1916, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7856, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1829, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8003, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1992, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8071, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1851, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8016, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1768, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7842, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1868, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7997, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1667, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7901, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1675, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8017, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1615, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8058, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1551, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8279, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1591, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8274, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1549, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8362, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1601, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8068, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1657, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8244, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1660, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8237, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1624, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8089, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1594, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8129, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1424, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8169, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1604, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8285, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1687, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8259, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1658, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8193, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1560, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8305, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1541, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.7957, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1554, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8160, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1376, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8303, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1408, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8301, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1380, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8531, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1389, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8285, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1302, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8193, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1466, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8035, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1558, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8293, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1457, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8322, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1365, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8508, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1376, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8335, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1122, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8498, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1201, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8502, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1186, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8587, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1164, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8384, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1310, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8242, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1234, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8274, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1262, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8330, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1382, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8354, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1362, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8328, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1403, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8358, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1267, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8425, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1275, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8344, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1215, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8442, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1160, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8369, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1024, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8375, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1094, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8425, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1183, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8358, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1128, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8480, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1190, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8421, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1159, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8573, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1188, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8530, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1272, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8662, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1189, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8566, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1264, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8560, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1136, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8310, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1227, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8535, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1064, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8667, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1163, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8539, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1133, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8547, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1105, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8439, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1046, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8566, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1109, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8465, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1064, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8683, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0936, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8654, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1110, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8588, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1082, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8639, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0977, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8612, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1097, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8738, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0934, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8619, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1036, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8542, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0998, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8801, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0962, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8818, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0976, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8719, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0883, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8520, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0926, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8503, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1029, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8551, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.1112, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8558, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0946, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8606, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0979, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8677, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0900, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8792, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0922, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8675, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0880, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8739, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0850, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8762, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0888, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8706, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0784, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8797, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0781, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8608, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0924, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8607, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0965, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8647, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0916, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8734, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0930, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8919, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0937, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8888, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0829, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9016, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0912, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8887, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0823, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8766, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0875, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8724, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0853, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8786, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0902, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8677, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0920, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8681, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0866, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8609, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0808, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8788, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0838, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8866, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0828, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8893, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0749, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8827, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0755, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8784, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0689, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8931, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0647, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8980, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0779, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8873, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0745, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8978, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0741, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8879, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0709, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8782, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0806, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8840, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0757, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8808, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0822, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8907, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0770, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9014, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0760, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9097, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0675, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9043, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0708, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9007, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0747, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8964, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0688, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9033, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0728, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9013, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0759, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9049, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0708, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8793, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0722, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8926, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0713, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8943, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0703, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9002, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0673, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9099, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0667, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9093, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0652, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9006, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0541, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8975, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0707, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8907, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0669, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8990, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0665, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9024, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0670, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8988, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0678, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8931, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0723, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8907, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0712, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.8961, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0688, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9028, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0645, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9038, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0713, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9051, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# ...
# preds -------------- min TensorBase(0.0346, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9361, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0357, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9357, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0362, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9341, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0371, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9331, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0435, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9338, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0373, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9385, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0448, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9468, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0425, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9530, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0482, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9456, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0452, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9419, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0434, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9324, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0460, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9450, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0409, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9426, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0400, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9427, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0378, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9319, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0382, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9309, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0349, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9239, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0398, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9314, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0391, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9431, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0405, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9537, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0459, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9609, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0411, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9396, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0444, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9364, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0437, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9328, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0394, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9301, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0440, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9366, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0433, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9341, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0369, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9338, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0324, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9364, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0361, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9285, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0391, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9305, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0424, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9262, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0374, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9437, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0411, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9445, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0413, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9417, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0424, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9527, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0401, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9528, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0378, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9433, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0367, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9441, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0367, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9340, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0376, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9281, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0367, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9403, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0424, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9418, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0433, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9449, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0442, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9442, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0446, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9438, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0380, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9369, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0391, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9484, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0376, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9376, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0386, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9331, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0387, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9386, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0357, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9309, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0377, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9333, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0334, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9385, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0401, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9432, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0421, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9505, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0455, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9547, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0404, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9474, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0390, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9419, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0318, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9467, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0354, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9418, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0403, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9407, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0393, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9386, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0394, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9424, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0349, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9342, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0377, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9449, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0334, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9496, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0343, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9311, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0400, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9391, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0411, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9311, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0387, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9354, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0379, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9311, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0438, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9443, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0421, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9439, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0366, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9455, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0382, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9598, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0330, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9491, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0334, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9547, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0337, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9514, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0377, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9474, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0338, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9513, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# L1 Loss: 0.29858
# preds -------------- min TensorBase(0.0333, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9466, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0392, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9411, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0
# preds -------------- min TensorBase(0.0437, device='cuda:0', grad_fn=<AliasBackward0>),max TensorBase(0.9414, device='cuda:0', grad_fn=<AliasBackward0>)
# origs -------------- min 0.0,max 1.0

# %%
def train_model(model, train_dl, opt, criterion, epochs, val_dl, visualize_every = 200):
    for e in range(epochs):
        loss_meter = AverageMeter()
        val_loss_meter = AverageMeter()
        counter = 0

        for data in tqdm(train_dl):
            L, ab = data['L'].to(device), data['ab'].to(device)
            preds = model(L)

            # visualize predicted images and loss every visualize_every cycles
            counter += 1
            if counter % visualize_every == 0:
              visualize_images(L.detach(),ab.detach(),preds.detach())      
              print(f"L1 Loss: {loss_meter.avg:.5f}")

            loss = criterion(preds, ab)
            opt.zero_grad()
            loss.backward()
            opt.step()
            loss_meter.update(loss.item(), L.size(0))
        print(f"Epoch {e + 1}/{epochs}")
        print(f"L1 Loss: {loss_meter.avg:.5f}")
        for data in tqdm(val_dl):
            L, ab = data['L'].to(device), data['ab'].to(device)
            preds = model(L)
            loss = criterion(preds, ab)
            val_loss_meter.update(loss.item(), L.size(0))
        print(f"L1 Validation Loss: {val_loss_meter.avg:.5f}")

unet = ResUnet(n_input=1, n_output=3, size=256)
opt = optim.Adam(unet.parameters(), lr=1e-4)
criterion = nn.L1Loss()
num_epochs = 2
train_model(unet, train_dl, opt, criterion, num_epochs, val_dl)
torch.save(unet.state_dict(), "res18-unet.pt")

# %%
plt.figure()
plt.plot(L1_distance_array)
plt.plot(MSE_distance_array)

# %% [markdown]
# ### 2.3 - Load previously trained model

# %%
unet.load_state_dict(torch.load("res18-unet.pt", map_location=device))

# %%
# !pip install torchviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from torchviz) (1.9.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.8/dist-packages (from torchviz) (0.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->torchviz) (4.4.0)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4151 sha256=3edb1e562f45586ec765272090af60c54753a18cea48f168f78ed045b16b85b0
#   Stored in directory: /root/.cache/pip/wheels/05/7d/1b/8306781244e42ede119edbb053bdcda1c1f424ca226165a417
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.2

# %%
from torchviz import make_dot

x = torch.randn(256, 256).view(1,1,256,256).to(device)
make_dot(unet(x), params=dict(unet.named_parameters()))

# %%
str(10)
# Out:
# '10'
